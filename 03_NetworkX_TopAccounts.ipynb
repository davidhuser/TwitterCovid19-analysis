# %%
# !pip install matplotlib

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import csv

def load_from_file(region):
    g = nx.DiGraph()
    
    with open('nodelist_{}.csv'.format(region), 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            g.add_nodes_from(row)
    
    edges = list()
    with open('edgelist_{}.csv'.format(region), 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            edges.append((row['Source'], row['Target']))
    g.add_edges_from(edges)
    
    return g

# %%
DB_HOST = '89.145.163.87'
DB_PORT = 5432
DB_USERNAME = 'group11'
DB_PASSWORD = 'tsw2020'
DB_NAME = 'tweets'

# %%
import psycopg2
import pandas as pd

def db_to_pandas(query):
    """ Query database to a Pandas DF"""
    conn = psycopg2.connect(host=DB_HOST, port=DB_PORT, database=DB_NAME, user=DB_USERNAME, password=DB_PASSWORD)
    cur = conn.cursor()
    df = pd.read_sql_query(query, conn)    
    cur.close()
    conn.close()
    return df

# %%
import operator
import pandas as pd

def get_network_stats(region):
    graph = load_from_file(region)
    print("*** {} - Analyzing network of {} nodes and {} edges".format(region, graph.order(), graph.size()))
   
    dc = nx.degree_centrality(graph)
    dc_avg = sum(dc.values()) / len(dc.values())
    dc_top = sorted(dc.items(), key=operator.itemgetter(1), reverse=True)[:10]
    print("DC avg: {}".format(dc_avg))
    
    
    ec = nx.eigenvector_centrality(graph)
    ec_avg = sum(ec.values()) / len(ec.values())
    ec_top = sorted(ec.items(), key=operator.itemgetter(1), reverse=True)[:10]
    print("EC avg: {}".format(ec_avg))
    
    
    cc = nx.closeness_centrality(graph)
    cc_avg = sum(cc.values()) / len(cc.values())
    cc_top = sorted(cc.items(), key=operator.itemgetter(1), reverse=True)[:10]
    print("CC avg: {}".format(cc_avg))

    k = int(float(graph.order())*float(graph.size())/3000000)
    print(k)
    bc = nx.betweenness_centrality(graph, k=k)
    bc_avg = sum(bc.values()) / len(bc.values())
    bc_top = sorted(bc.items(), key=operator.itemgetter(1), reverse=True)[:10]
    print("BC avg: {}".format(bc_avg))
    
    dc_df = pd.DataFrame(dc_top, columns=['id_str', 'degree_centrality']).set_index('id_str')
    ec_df = pd.DataFrame(ec_top, columns=['id_str', 'eigenvector_centrality']).set_index('id_str')
    cc_df = pd.DataFrame(cc_top, columns=['id_str', 'closeness_centrality']).set_index('id_str')
    bc_df = pd.DataFrame(bc_top, columns=['id_str', 'betweenness_centrality']).set_index('id_str')


    return pd.concat([dc_df, ec_df, cc_df, bc_df], axis=1, sort=False)\
.reset_index().rename(columns={'index': 'id_str'})

# %%
def get_account(id_str):
    sql_query="""
    SELECT DISTINCT tweet_body->'user'->>'screen_name' as screen_name
    FROM tweet
    WHERE tweet_body->'user'->>'id_str' = '{}';
    """.format(id_str)
    
    q = db_to_pandas(sql_query)['screen_name']
    return q

# %%
df = get_network_stats('netherlands')
df
# Out:
# *** netherlands - Analyzing network of 21768 nodes and 31531 edges
# DC avg: 0.00013309159634562021
# EC avg: 0.002083930536593513
# CC avg: 0.003998423765220624
# 228
# BC avg: 9.000892122832056e-06
#                  id_str  degree_centrality  eigenvector_centrality  \
# 0              35527415           0.155051                     NaN
# 1              41778159           0.061239                     NaN
# 2             367703310           0.037626                     NaN
# 3             124280192           0.036753                     NaN
# 4   1024256932834631680           0.020260                     NaN
# 5            4715788289           0.019479                     NaN
# 6            3233835926           0.018606                     NaN
# 7   1085897362550202369           0.018331                     NaN
# 8             194774819           0.018101                     NaN
# 9              15537007           0.017687                     NaN
# 10           1340408646                NaN                0.148042
# 11  1103059945245863937                NaN                0.127263
# 12            107209093                NaN                0.126240
# 13            154645514                NaN                0.109290
# 14            610558969                NaN                0.108867
# 15            452361510                NaN                0.102816
# 16           4845768045                NaN                0.097910
# 17            214046074                NaN                0.093333
# 18   842067043012739073                NaN                0.092849
# 19            190648628                NaN                0.091581
# 20           4181682291                NaN                     NaN
# 21            305405655                NaN                     NaN
# 22   748157123830358017                NaN                     NaN
# 23            199397015                NaN                     NaN
# 24            135512400                NaN                     NaN
# 25             19119318                NaN                     NaN
# 26   810603440984494080                NaN                     NaN
# 27           2799594860                NaN                     NaN
# 28            216338982                NaN                     NaN
#
#     closeness_centrality  betweenness_centrality
# 0                    NaN                0.020247
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
# 5                    NaN                     NaN
# 6                    NaN                     NaN
# 7                    NaN                     NaN
# 8                    NaN                     NaN
# 9                    NaN                     NaN
# 10              0.014809                0.010217
# 11              0.014784                     NaN
# 12              0.016114                     NaN
# 13                   NaN                     NaN
# 14              0.015417                0.005099
# 15                   NaN                     NaN
# 16                   NaN                     NaN
# 17              0.015565                     NaN
# 18              0.014325                     NaN
# 19              0.015273                     NaN
# 20              0.014886                0.004312
# 21              0.014212                     NaN
# 22              0.014202                     NaN
# 23                   NaN                0.019646
# 24                   NaN                0.007684
# 25                   NaN                0.005514
# 26                   NaN                0.005071
# 27                   NaN                0.004370
# 28                   NaN                0.004317

# %%
# look up screen name
df['screen_name'] = df['id_str'].apply(lambda x: get_account(x))

# round
df.round({
    'degree_centrality': 5, 
    'eigenvector_centrality': 5, 
    'closeness_centrality': 5, 
    'betweenness_centrality': 5
})

df
# Out:
#                  id_str  degree_centrality  eigenvector_centrality  \
# 0              35527415           0.155051                     NaN
# 1              41778159           0.061239                     NaN
# 2             367703310           0.037626                     NaN
# 3             124280192           0.036753                     NaN
# 4   1024256932834631680           0.020260                     NaN
# 5            4715788289           0.019479                     NaN
# 6            3233835926           0.018606                     NaN
# 7   1085897362550202369           0.018331                     NaN
# 8             194774819           0.018101                     NaN
# 9              15537007           0.017687                     NaN
# 10           1340408646                NaN                0.148042
# 11  1103059945245863937                NaN                0.127263
# 12            107209093                NaN                0.126240
# 13            154645514                NaN                0.109290
# 14            610558969                NaN                0.108867
# 15            452361510                NaN                0.102816
# 16           4845768045                NaN                0.097910
# 17            214046074                NaN                0.093333
# 18   842067043012739073                NaN                0.092849
# 19            190648628                NaN                0.091581
# 20           4181682291                NaN                     NaN
# 21            305405655                NaN                     NaN
# 22   748157123830358017                NaN                     NaN
# 23            199397015                NaN                     NaN
# 24            135512400                NaN                     NaN
# 25             19119318                NaN                     NaN
# 26   810603440984494080                NaN                     NaN
# 27           2799594860                NaN                     NaN
# 28            216338982                NaN                     NaN
#
#     closeness_centrality  betweenness_centrality      screen_name
# 0                    NaN                0.020247             rivm
# 1                    NaN                     NaN  geertwilderspvv
# 2                    NaN                     NaN    thierrybaudet
# 3                    NaN                     NaN  VogelvrijeHArts
# 4                    NaN                     NaN     RebeccaH2020
# 5                    NaN                     NaN     FHvanLeeuwen
# 6                    NaN                     NaN   jodigraphics15
# 7                    NaN                     NaN     Sashaexposed
# 8                    NaN                     NaN       EricArends
# 9                    NaN                     NaN   martinenserink
# 10              0.014809                0.010217      Hannesz1956
# 11              0.014784                     NaN         MIsBack8
# 12              0.016114                     NaN        maryfloor
# 13                   NaN                     NaN         angelb52
# 14              0.015417                0.005099          visuele
# 15                   NaN                     NaN     YvonnedeMoor
# 16                   NaN                     NaN   WereldPijnCafe
# 17              0.015565                     NaN       pimbrussee
# 18              0.014325                     NaN   marco_kerkhofs
# 19              0.015273                     NaN         marizsmn
# 20              0.014886                0.004312          NLstaat
# 21              0.014212                     NaN          MiepieB
# 22              0.014202                     NaN    RonNagtegaal1
# 23                   NaN                0.019646        arzubarsk
# 24                   NaN                0.007684    sandervanluit
# 25                   NaN                0.005514       lisakarina
# 26                   NaN                0.005071      Vickyvdtogt
# 27                   NaN                0.004370      ytekedejong
# 28                   NaN                0.004317        gemHouten

# %%
df.to_csv('account_stats.csv')
